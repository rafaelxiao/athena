# %%
import pandas as pd
import numpy as np
import tushare as ts
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import auc, roc_curve, confusion_matrix, precision_recall_curve, average_precision_score
from sklearn.svm import SVC
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM
from keras.utils import to_categorical
# Out:
# Using TensorFlow backend.

# %%
tick_ori = ts.get_k_data('600313', start='2010-01-01', end='2018-01-23')

# %%
tick = pd.DataFrame.copy(tick_ori)
tick = tick[tick['high'] != tick['low']].reset_index().drop('index', axis=1)

# %%
def get_box(p_open, p_close, p_high, p_low):
    if p_high == p_low:
        p_high = max(p_open, p_close, p_high, p_low)
        p_low = min(p_open, p_close, p_high, p_low)
    max_range = (p_high - p_low)
    move = p_close - p_open
    top = min(p_high - p_open, p_high - p_close) / max_range
    middle = abs(p_open - p_close) / max_range
    bottom = min(p_close - p_low, p_open - p_low) / max_range
    return [move, top, middle, bottom]

# %%
tick['move'] = tick.apply(lambda x: get_box(x['open'], x['close'], x['high'], x['low'])[0], axis=1)
tick['top'] = tick.apply(lambda x: get_box(x['open'], x['close'], x['high'], x['low'])[1], axis=1)
tick['middle'] = tick.apply(lambda x: get_box(x['open'], x['close'], x['high'], x['low'])[2], axis=1)
tick['bottom'] = tick.apply(lambda x: get_box(x['open'], x['close'], x['high'], x['low'])[3], axis=1)
tick['median'] = tick.apply(lambda x: (x['high'] + x['close']) / 2, axis=1)

# %%
scaler = MinMaxScaler((0, 1))
tick['move_scaled'] = scaler.fit_transform(tick['move'].values.reshape(-1 , 1))
tick['median'] = scaler.fit_transform(tick['median'].values.reshape(-1 , 1))
tick['volume'] = scaler.fit_transform(tick['volume'].values.reshape(-1 , 1))

# %%
def get_frame(df, x_cols, y_cols, duration=10, forward=1, thread=0.01):
    tick = pd.DataFrame.copy(df)
    Xs = []
    ys = []
    for i in range(duration, len(tick) - forward + 1):
        h_x = tick.loc[i-duration: i-1, x_cols].as_matrix()
        forward_high = max(tick.loc[i: i + forward - 1, y_cols[0]])
        h_y = np.array(1 if (forward_high - tick.loc[i, y_cols[1]]) / tick.loc[i, y_cols[1]] >= thread else 0)
        Xs.append(h_x)
        ys.append(h_y)
    Xs = np.array(Xs)
    ys = to_categorical(np.array(ys), 2)
    return [Xs, ys]

# %%
x_cols = ['median', 'volume', 'move_scaled', 'top', 'middle', 'bottom']
# x_cols = ['move_scaled', 'middle']
# x_cols = ['move_scaled', 'top', 'middle', 'bottom']
y_cols = ['high', 'close']

thread = 0.09
duration = 20
forward = 20

X, y = get_frame(tick, x_cols, y_cols, thread=thread, duration=duration, forward=forward)
sum(y[:, 1]) / len(y)
# Out:
# 0.50440081245768453

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
model = Sequential()
model.add(LSTM(16, input_shape=(duration, len(x_cols)), activation='relu', return_sequences=True))
# model.add(Dropout(0.5))
# model.add(LSTM(16, activation='relu', return_sequences=True))
model.add(Dropout(0.5))
model.add(LSTM(16, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(2, activation='sigmoid'))

model.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

# %%
model.fit(X_train, y_train, batch_size=32, epochs=100, validation_split=0.2)
# Out:
# Train on 885 samples, validate on 222 samples
# Epoch 1/100
# 885/885 [==============================] - 2s 2ms/step - loss: 0.6934 - acc: 0.4994 - val_loss: 0.6935 - val_acc: 0.4775
# Epoch 2/100
# 885/885 [==============================] - 0s 496us/step - loss: 0.6933 - acc: 0.5006 - val_loss: 0.6934 - val_acc: 0.4775
# Epoch 3/100
# 885/885 [==============================] - 0s 500us/step - loss: 0.6931 - acc: 0.5096 - val_loss: 0.6932 - val_acc: 0.4865
# Epoch 4/100
# 885/885 [==============================] - 0s 495us/step - loss: 0.6933 - acc: 0.4960 - val_loss: 0.6931 - val_acc: 0.5000
# Epoch 5/100
# 885/885 [==============================] - 0s 509us/step - loss: 0.6933 - acc: 0.4870 - val_loss: 0.6928 - val_acc: 0.5676
# Epoch 6/100
# 885/885 [==============================] - 0s 517us/step - loss: 0.6928 - acc: 0.5209 - val_loss: 0.6921 - val_acc: 0.5225
# Epoch 7/100
# 885/885 [==============================] - 0s 502us/step - loss: 0.6934 - acc: 0.4983 - val_loss: 0.6919 - val_acc: 0.5225
# Epoch 8/100
# 885/885 [==============================] - 0s 497us/step - loss: 0.6925 - acc: 0.5333 - val_loss: 0.6911 - val_acc: 0.5225
# Epoch 9/100
# 885/885 [==============================] - 0s 502us/step - loss: 0.6922 - acc: 0.5096 - val_loss: 0.6907 - val_acc: 0.5721
# Epoch 10/100
# 885/885 [==============================] - 1s 581us/step - loss: 0.6914 - acc: 0.5435 - val_loss: 0.6883 - val_acc: 0.5180
# Epoch 11/100
# 885/885 [==============================] - 1s 670us/step - loss: 0.6931 - acc: 0.4960 - val_loss: 0.6881 - val_acc: 0.5766
# Epoch 12/100
# 885/885 [==============================] - 1s 668us/step - loss: 0.6916 - acc: 0.5446 - val_loss: 0.6907 - val_acc: 0.5270
# Epoch 13/100
# 885/885 [==============================] - 1s 667us/step - loss: 0.6907 - acc: 0.5367 - val_loss: 0.6868 - val_acc: 0.5225
# Epoch 14/100
# 885/885 [==============================] - 1s 675us/step - loss: 0.6912 - acc: 0.5311 - val_loss: 0.6868 - val_acc: 0.5946
# Epoch 15/100
# 885/885 [==============================] - 1s 675us/step - loss: 0.6901 - acc: 0.5322 - val_loss: 0.6841 - val_acc: 0.4910
# Epoch 16/100
# 885/885 [==============================] - 1s 666us/step - loss: 0.6939 - acc: 0.5254 - val_loss: 0.6881 - val_acc: 0.5766
# Epoch 17/100
# 885/885 [==============================] - 1s 668us/step - loss: 0.6873 - acc: 0.5627 - val_loss: 0.6869 - val_acc: 0.5721
# Epoch 18/100
# 885/885 [==============================] - 1s 667us/step - loss: 0.6861 - acc: 0.5729 - val_loss: 0.6811 - val_acc: 0.5811
# Epoch 19/100
# 885/885 [==============================] - 1s 666us/step - loss: 0.6867 - acc: 0.5729 - val_loss: 0.6768 - val_acc: 0.5586
# Epoch 20/100
# 885/885 [==============================] - 1s 670us/step - loss: 0.6863 - acc: 0.5469 - val_loss: 0.6798 - val_acc: 0.5946
# Epoch 21/100
# 885/885 [==============================] - 1s 668us/step - loss: 0.6753 - acc: 0.5661 - val_loss: 0.6796 - val_acc: 0.5856
# Epoch 22/100
# 885/885 [==============================] - 1s 652us/step - loss: 0.6823 - acc: 0.5435 - val_loss: 0.6768 - val_acc: 0.6126
# Epoch 23/100
# 885/885 [==============================] - 1s 667us/step - loss: 0.6768 - acc: 0.5797 - val_loss: 0.6704 - val_acc: 0.6081
# Epoch 24/100
# 885/885 [==============================] - 1s 664us/step - loss: 0.6737 - acc: 0.5966 - val_loss: 0.6766 - val_acc: 0.5721
# Epoch 25/100
# 885/885 [==============================] - 1s 667us/step - loss: 0.6693 - acc: 0.6068 - val_loss: 0.6669 - val_acc: 0.5856
# Epoch 26/100
# 885/885 [==============================] - 1s 662us/step - loss: 0.6642 - acc: 0.5944 - val_loss: 0.6658 - val_acc: 0.6351
# Epoch 27/100
# 885/885 [==============================] - 1s 664us/step - loss: 0.6541 - acc: 0.6034 - val_loss: 0.6555 - val_acc: 0.6081
# Epoch 28/100
# 885/885 [==============================] - 1s 665us/step - loss: 0.6568 - acc: 0.6045 - val_loss: 0.6737 - val_acc: 0.5766
# Epoch 29/100
# 885/885 [==============================] - 1s 673us/step - loss: 0.6560 - acc: 0.6113 - val_loss: 0.6603 - val_acc: 0.6216
# Epoch 30/100
# 885/885 [==============================] - 1s 669us/step - loss: 0.6742 - acc: 0.6102 - val_loss: 0.6691 - val_acc: 0.6171
# Epoch 31/100
# 885/885 [==============================] - 1s 667us/step - loss: 0.6610 - acc: 0.6068 - val_loss: 0.6594 - val_acc: 0.6261
# Epoch 32/100
# 885/885 [==============================] - 1s 675us/step - loss: 0.6635 - acc: 0.6260 - val_loss: 0.6411 - val_acc: 0.6171
# Epoch 33/100
# 885/885 [==============================] - 1s 659us/step - loss: 0.6525 - acc: 0.6102 - val_loss: 0.6555 - val_acc: 0.6396
# Epoch 34/100
# 885/885 [==============================] - 1s 680us/step - loss: 0.6561 - acc: 0.6316 - val_loss: 0.6530 - val_acc: 0.6081
# Epoch 35/100
# 885/885 [==============================] - 1s 683us/step - loss: 0.6486 - acc: 0.6305 - val_loss: 0.6596 - val_acc: 0.5991
# Epoch 36/100
# 885/885 [==============================] - 1s 671us/step - loss: 0.6517 - acc: 0.6441 - val_loss: 0.6449 - val_acc: 0.6306
# Epoch 37/100
# 885/885 [==============================] - 1s 670us/step - loss: 0.6450 - acc: 0.6068 - val_loss: 0.6474 - val_acc: 0.6306
# Epoch 38/100
#  - ETA: 0s - loss: 0.6398 - acc: 0.6562
# Epoch 39/100
# 885/885 [==============================] - 1s 666us/step - loss: 0.6377 - acc: 0.6328 - val_loss: 0.6499 - val_acc: 0.6351
# Epoch 40/100
# 885/885 [==============================] - 1s 665us/step - loss: 0.6452 - acc: 0.6271 - val_loss: 0.6397 - val_acc: 0.6351
# Epoch 41/100
# 885/885 [==============================] - 1s 667us/step - loss: 0.6535 - acc: 0.6147 - val_loss: 0.6508 - val_acc: 0.6351
# Epoch 42/100
# 885/885 [==============================] - 1s 670us/step - loss: 0.6462 - acc: 0.6215 - val_loss: 0.6416 - val_acc: 0.6396
# Epoch 43/100
# 885/885 [==============================] - 1s 670us/step - loss: 0.6385 - acc: 0.6282 - val_loss: 0.6380 - val_acc: 0.6261
# Epoch 44/100
# 885/885 [==============================] - 1s 665us/step - loss: 0.6459 - acc: 0.6226 - val_loss: 0.6387 - val_acc: 0.6622
# Epoch 45/100
# 885/885 [==============================] - 1s 676us/step - loss: 0.6459 - acc: 0.6328 - val_loss: 0.6478 - val_acc: 0.6441
# Epoch 46/100
# 885/885 [==============================] - 1s 669us/step - loss: 0.6458 - acc: 0.6249 - val_loss: 0.6404 - val_acc: 0.6486
# Epoch 47/100
# 885/885 [==============================] - 1s 674us/step - loss: 0.6445 - acc: 0.6407 - val_loss: 0.6353 - val_acc: 0.6532
# Epoch 48/100
# 885/885 [==============================] - 1s 709us/step - loss: 0.6328 - acc: 0.6316 - val_loss: 0.6392 - val_acc: 0.6441
# Epoch 49/100
# 885/885 [==============================] - 1s 676us/step - loss: 0.6295 - acc: 0.6395 - val_loss: 0.6261 - val_acc: 0.6577
# Epoch 50/100
# 885/885 [==============================] - 1s 676us/step - loss: 0.6382 - acc: 0.6407 - val_loss: 0.6414 - val_acc: 0.6171
# Epoch 51/100
# 885/885 [==============================] - 1s 676us/step - loss: 0.6426 - acc: 0.6350 - val_loss: 0.6366 - val_acc: 0.6486
# Epoch 52/100
# 885/885 [==============================] - 1s 676us/step - loss: 0.6251 - acc: 0.6486 - val_loss: 0.6307 - val_acc: 0.6306
# Epoch 53/100
# 885/885 [==============================] - 1s 673us/step - loss: 0.6313 - acc: 0.6497 - val_loss: 0.6388 - val_acc: 0.6216
# Epoch 54/100
# 885/885 [==============================] - 1s 678us/step - loss: 0.6216 - acc: 0.6463 - val_loss: 0.6292 - val_acc: 0.6757
# Epoch 55/100
# 885/885 [==============================] - 1s 679us/step - loss: 0.6191 - acc: 0.6339 - val_loss: 0.6453 - val_acc: 0.6396
# Epoch 56/100
# 885/885 [==============================] - 1s 673us/step - loss: 0.6277 - acc: 0.6452 - val_loss: 0.6397 - val_acc: 0.6216
# Epoch 57/100
# 885/885 [==============================] - 1s 678us/step - loss: 0.6351 - acc: 0.6497 - val_loss: 0.6301 - val_acc: 0.6802
# Epoch 58/100
# 885/885 [==============================] - 1s 683us/step - loss: 0.6155 - acc: 0.6520 - val_loss: 0.6290 - val_acc: 0.6351
# Epoch 59/100
# 885/885 [==============================] - 1s 676us/step - loss: 0.6153 - acc: 0.6508 - val_loss: 0.6186 - val_acc: 0.6802
# Epoch 60/100
# 885/885 [==============================] - 1s 681us/step - loss: 0.6160 - acc: 0.6475 - val_loss: 0.6234 - val_acc: 0.6351
# Epoch 61/100
# 885/885 [==============================] - 1s 700us/step - loss: 0.6066 - acc: 0.6621 - val_loss: 0.6439 - val_acc: 0.6306
# Epoch 62/100
# 885/885 [==============================] - 1s 697us/step - loss: 0.6283 - acc: 0.6554 - val_loss: 0.6216 - val_acc: 0.6486
# Epoch 63/100
# 885/885 [==============================] - 1s 689us/step - loss: 0.6077 - acc: 0.6621 - val_loss: 0.6301 - val_acc: 0.6441
# Epoch 64/100
# 885/885 [==============================] - 1s 686us/step - loss: 0.6149 - acc: 0.6599 - val_loss: 0.6234 - val_acc: 0.6396
# Epoch 65/100
# 885/885 [==============================] - 1s 689us/step - loss: 0.6103 - acc: 0.6667 - val_loss: 0.6227 - val_acc: 0.6486
# Epoch 66/100
# 885/885 [==============================] - 1s 689us/step - loss: 0.6052 - acc: 0.6531 - val_loss: 0.6177 - val_acc: 0.6351
# Epoch 67/100
# 885/885 [==============================] - 1s 679us/step - loss: 0.5967 - acc: 0.6746 - val_loss: 0.6205 - val_acc: 0.6126
# Epoch 68/100
# 885/885 [==============================] - 1s 675us/step - loss: 0.6011 - acc: 0.6757 - val_loss: 0.6170 - val_acc: 0.6532
# Epoch 69/100
# 885/885 [==============================] - 1s 675us/step - loss: 0.6041 - acc: 0.6644 - val_loss: 0.6103 - val_acc: 0.6622
# Epoch 70/100
# 885/885 [==============================] - 1s 678us/step - loss: 0.5952 - acc: 0.6701 - val_loss: 0.6049 - val_acc: 0.6667
# Epoch 71/100
# 885/885 [==============================] - 1s 689us/step - loss: 0.5931 - acc: 0.6893 - val_loss: 0.5999 - val_acc: 0.6757
# Epoch 72/100
# 885/885 [==============================] - 1s 681us/step - loss: 0.6046 - acc: 0.6734 - val_loss: 0.6043 - val_acc: 0.6532
# Epoch 73/100
# 885/885 [==============================] - 1s 677us/step - loss: 0.5907 - acc: 0.6814 - val_loss: 0.6100 - val_acc: 0.6486
# Epoch 74/100
# 885/885 [==============================] - 1s 689us/step - loss: 0.5897 - acc: 0.6847 - val_loss: 0.6450 - val_acc: 0.6486
# Epoch 75/100
# 885/885 [==============================] - 1s 676us/step - loss: 0.5831 - acc: 0.6734 - val_loss: 0.5977 - val_acc: 0.6892
# Epoch 76/100
# 885/885 [==============================] - 1s 680us/step - loss: 0.5903 - acc: 0.6780 - val_loss: 0.6100 - val_acc: 0.6757
# Epoch 77/100
# 885/885 [==============================] - 1s 688us/step - loss: 0.5927 - acc: 0.6938 - val_loss: 0.5936 - val_acc: 0.6982
# Epoch 78/100
# 885/885 [==============================] - 1s 675us/step - loss: 0.5772 - acc: 0.6938 - val_loss: 0.6117 - val_acc: 0.6847
# Epoch 79/100
# 885/885 [==============================] - 1s 683us/step - loss: 0.5781 - acc: 0.6802 - val_loss: 0.5865 - val_acc: 0.7027
# Epoch 80/100
# 885/885 [==============================] - 1s 681us/step - loss: 0.5833 - acc: 0.6949 - val_loss: 0.6102 - val_acc: 0.6892
# Epoch 81/100
# 885/885 [==============================] - 1s 681us/step - loss: 0.5775 - acc: 0.6904 - val_loss: 0.6077 - val_acc: 0.6847
# Epoch 82/100
# 885/885 [==============================] - 1s 676us/step - loss: 0.5746 - acc: 0.6893 - val_loss: 0.5986 - val_acc: 0.6577
# Epoch 83/100
# 885/885 [==============================] - 1s 680us/step - loss: 0.5791 - acc: 0.6949 - val_loss: 0.6267 - val_acc: 0.6622
# Epoch 84/100
# 885/885 [==============================] - 1s 681us/step - loss: 0.5640 - acc: 0.7006 - val_loss: 0.6570 - val_acc: 0.6622
# Epoch 85/100
# 885/885 [==============================] - 1s 677us/step - loss: 0.5725 - acc: 0.6983 - val_loss: 0.6130 - val_acc: 0.6667
# Epoch 86/100
# 885/885 [==============================] - 1s 684us/step - loss: 0.5771 - acc: 0.7028 - val_loss: 0.5844 - val_acc: 0.7072
# Epoch 87/100
# 885/885 [==============================] - 1s 676us/step - loss: 0.5666 - acc: 0.6915 - val_loss: 0.5876 - val_acc: 0.6937
# Epoch 88/100
# 885/885 [==============================] - 1s 673us/step - loss: 0.5607 - acc: 0.6859 - val_loss: 0.5949 - val_acc: 0.6892
# Epoch 89/100
# 885/885 [==============================] - 1s 674us/step - loss: 0.5786 - acc: 0.6915 - val_loss: 0.5882 - val_acc: 0.6937
# Epoch 90/100
# 885/885 [==============================] - 1s 675us/step - loss: 0.5568 - acc: 0.7073 - val_loss: 0.5880 - val_acc: 0.6802
# Epoch 91/100
# 885/885 [==============================] - 1s 673us/step - loss: 0.5659 - acc: 0.7040 - val_loss: 0.6416 - val_acc: 0.6486
# Epoch 92/100
# 885/885 [==============================] - 1s 669us/step - loss: 0.5611 - acc: 0.6994 - val_loss: 0.5880 - val_acc: 0.7297
# Epoch 93/100
# 885/885 [==============================] - 1s 673us/step - loss: 0.5619 - acc: 0.6938 - val_loss: 0.5783 - val_acc: 0.6892
# Epoch 94/100
# 885/885 [==============================] - 1s 667us/step - loss: 0.5571 - acc: 0.7073 - val_loss: 0.5963 - val_acc: 0.7072
# Epoch 95/100
# 885/885 [==============================] - 1s 673us/step - loss: 0.5523 - acc: 0.7085 - val_loss: 0.5848 - val_acc: 0.7072
# Epoch 96/100
# 885/885 [==============================] - 1s 679us/step - loss: 0.5609 - acc: 0.6870 - val_loss: 0.5960 - val_acc: 0.7027
# Epoch 97/100
# 885/885 [==============================] - 1s 669us/step - loss: 0.5524 - acc: 0.7130 - val_loss: 0.5838 - val_acc: 0.6847
# Epoch 98/100
# 885/885 [==============================] - 1s 714us/step - loss: 0.5552 - acc: 0.7107 - val_loss: 0.6062 - val_acc: 0.7072
# Epoch 99/100
# 885/885 [==============================] - 1s 720us/step - loss: 0.5352 - acc: 0.7186 - val_loss: 0.5773 - val_acc: 0.7162
# Epoch 100/100
# 885/885 [==============================] - 1s 706us/step - loss: 0.5508 - acc: 0.7186 - val_loss: 0.5761 - val_acc: 0.7162

# %%
y_test_predicted = [np.argmax(i) for i in model.predict(X_test)]
y_test_actual = [np.argmax(i) for i in y_test]
tn, fp, fn, tp = confusion_matrix(y_test_actual, y_test_predicted).ravel()
print(tn, fp, fn, tp)
print("percision: %.4f"%(tp / (tp + fp)))
print("recall: %.4f"%(tp / (tp + fn)))
# Out:
# 125 59 61 125
# percision: 0.6793
# recall: 0.6720
